# %% [markdown]
# # Step 4: Driver Analysis & Multi-Factor Performance Decomposition
# **Objective**: Identify WHY collections performance changed over 12 months using the Golden Dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_scorecard = pd.read_csv('../data/golden/driver_scorecard.csv')
df_monthly = pd.read_csv('../data/golden/monthly_performance.csv')
display(df_scorecard)

# %% [markdown]
# ## Driver Scorecard Analysis
# Ranking top operational drivers by impact and evidence strength.

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_monthly['month'], df_monthly['recovery_per_account_inr'], marker='o', color='crimson')
plt.title('Recovery per Account Over Time (April Cliff Drop)')
plt.ylabel('Recovery / Account (INR)')
plt.grid(True)
plt.show()
