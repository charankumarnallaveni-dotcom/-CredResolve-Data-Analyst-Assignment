# %% [markdown]
# # Step 5: Targeting Strategy Counterfactual Analysis
# **Objective**: Answer: *'What would recovery have looked like if we had NOT changed the targeting strategy?'*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_cf = pd.read_csv('../data/golden/counterfactual_results.csv')
display(df_cf)

# %% [markdown]
# ## Difference-in-Differences (DiD) Estimation
# Comparing treatment accounts (strategy v3) vs control accounts (strategy v2) before and after April 2026.

# %%
print('DiD Counterfactual Estimation Results:')
print('Actual Post-Period Recovery: INR', df_cf.loc[df_cf['metric'] == 'Observed Post-Period Recovery', 'value'].values[0])
print('Counterfactual Recovery:     INR', df_cf.loc[df_cf['metric'] == 'Counterfactual Post-Period Recovery', 'value'].values[0])
print('Net Incremental Loss:        INR', df_cf.loc[df_cf['metric'] == 'Net Incremental Recovery Loss', 'value'].values[0])
