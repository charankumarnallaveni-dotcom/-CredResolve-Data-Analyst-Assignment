# %% [markdown]
# # Step 6: INR 10 Crore Investment Decision Model
# **Objective**: Recommend exactly ONE investment option out of 6 candidates based on Golden Dataset evidence.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_inv = pd.read_csv('../data/golden/investment_comparison.csv')
display(df_inv[['option_name', 'base_incremental_recovery_12m', 'base_roi_pct', 'break_even_month', 'confidence_level', 'recommendation_status']])

# %% [markdown]
# ## 12-Month ROI Comparison Across Scenarios

# %%
plt.figure(figsize=(10, 5))
plt.barh(df_inv['option_name'], df_inv['base_roi_pct'], color='forestgreen')
plt.title('12-Month Base ROI (%) by Investment Option')
plt.xlabel('Base ROI (%)')
plt.grid(True)
plt.show()
